# %% [markdown]
# # Part 3: API Source
#
# ## NASA Asteroids - NeoWs API

# %% [markdown]
# ### Packages

# %%
import pandas as pd
import numpy as np
import json
import requests
from datetime import datetime as dt

# %% [markdown]
# ### The Data

# %% [markdown]
# Pull data from API. Can pull data for up to a 7 day period.

# %%
url = 'https://api.nasa.gov/neo/rest/v1/feed?'

# %%
api_key = 'byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'

# %%
start_date = '2020-01-01'

# %%
end_date = '2020-01-07'

# %%
r = requests.get(('{}start_date={}&end_date={}&api_key={}').format(url, start_date, end_date, api_key))

# %%
r
# Out:
# <Response [200]>

# %%
# convert to json

r_json = r.json()

# %%
r_json.keys()
# Out:
# dict_keys(['links', 'element_count', 'near_earth_objects'])

# %%
r_json
# Out:
# {'links': {'next': 'http://www.neowsapp.com/rest/v1/feed?start_date=2020-01-07&end_date=2020-01-13&detailed=false&api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV',
#   'prev': 'http://www.neowsapp.com/rest/v1/feed?start_date=2019-12-26&end_date=2020-01-01&detailed=false&api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV',
#   'self': 'http://www.neowsapp.com/rest/v1/feed?start_date=2020-01-01&end_date=2020-01-07&detailed=false&api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#  'element_count': 105,
#  'near_earth_objects': {'2020-01-01': [{'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3978225?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '3978225',
#     'neo_reference_id': '3978225',
#     'name': '(2020 AN2)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3978225',
#     'absolute_magnitude_h': 26.5,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0133215567,
#       'estimated_diameter_max': 0.0297879063},
#      'meters': {'estimated_diameter_min': 13.3215566698,
#       'estimated_diameter_max': 29.7879062798},
#      'miles': {'estimated_diameter_min': 0.008277629,
#       'estimated_diameter_max': 0.0185093411},
#      'feet': {'estimated_diameter_min': 43.7058959846,
#       'estimated_diameter_max': 97.7293544391}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2020-01-01',
#       'close_approach_date_full': '2020-Jan-01 21:18',
#       'epoch_date_close_approach': 1577913480000,
#       'relative_velocity': {'kilometers_per_second': '15.3528156363',
#        'kilometers_per_hour': '55270.1362905576',
#        'miles_per_hour': '34342.7132967634'},
#       'miss_distance': {'astronomical': '0.0202143162',
#        'lunar': '7.8633690018',
#        'kilometers': '3024018.647026494',
#        'miles': '1879038.0551098572'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3972421?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '3972421',
#     'neo_reference_id': '3972421',
#     'name': '(2020 AX)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3972421',
#     'absolute_magnitude_h': 26.3,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0146067964,
#       'estimated_diameter_max': 0.0326617897},
#      'meters': {'estimated_diameter_min': 14.6067964271,
#       'estimated_diameter_max': 32.6617897446},
#      'miles': {'estimated_diameter_min': 0.0090762397,
#       'estimated_diameter_max': 0.020295089},
#      'feet': {'estimated_diameter_min': 47.92256199,
#       'estimated_diameter_max': 107.1581062656}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2020-01-01',
#       'close_approach_date_full': '2020-Jan-01 22:49',
#       'epoch_date_close_approach': 1577918940000,
#       'relative_velocity': {'kilometers_per_second': '7.3167354067',
#        'kilometers_per_hour': '26340.2474640716',
#        'miles_per_hour': '16366.8054312171'},
#       'miss_distance': {'astronomical': '0.049656182',
#        'lunar': '19.316254798',
#        'kilometers': '7428459.05953234',
#        'miles': '4615830.420692692'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3893737?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '3893737',
#     'neo_reference_id': '3893737',
#     'name': '(2019 WE5)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3893737',
#     'absolute_magnitude_h': 23.0,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0667659413,
#       'estimated_diameter_max': 0.1492931834},
#      'meters': {'estimated_diameter_min': 66.7659413495,
#       'estimated_diameter_max': 149.2931834393},
#      'miles': {'estimated_diameter_min': 0.0414864197,
#       'estimated_diameter_max': 0.0927664547},
#      'feet': {'estimated_diameter_min': 219.0483710172,
#       'estimated_diameter_max': 489.807047955}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2020-01-01',
#       'close_approach_date_full': '2020-Jan-01 14:55',
#       'epoch_date_close_approach': 1577890500000,
#       'relative_velocity': {'kilometers_per_second': '5.0028249279',
#        'kilometers_per_hour': '18010.1697403975',
#        'miles_per_hour': '11190.8190811931'},
#       'miss_distance': {'astronomical': '0.1345974227',
#        'lunar': '52.3583974303',
#        'kilometers': '20135487.743409649',
#        'miles': '12511611.9126011962'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3976578?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '3976578',
#     'neo_reference_id': '3976578',
#     'name': '(2020 AE2)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3976578',
#     'absolute_magnitude_h': 22.9,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0699125232,
#       'estimated_diameter_max': 0.1563291544},
#      'meters': {'estimated_diameter_min': 69.9125232246,
#       'estimated_diameter_max': 156.3291544087},
#      'miles': {'estimated_diameter_min': 0.0434416145,
#       'estimated_diameter_max': 0.097138403},
#      'feet': {'estimated_diameter_min': 229.3718026961,
#       'estimated_diameter_max': 512.8909429502}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2020-01-01',
#       'close_approach_date_full': '2020-Jan-01 15:16',
#       'epoch_date_close_approach': 1577891760000,
#       'relative_velocity': {'kilometers_per_second': '13.2987974369',
#        'kilometers_per_hour': '47875.6707729516',
#        'miles_per_hour': '29748.079986671'},
#       'miss_distance': {'astronomical': '0.2371472028',
#        'lunar': '92.2502618892',
#        'kilometers': '35476716.415338036',
#        'miles': '22044209.3769194568'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3591759?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '3591759',
#     'neo_reference_id': '3591759',
#     'name': '(2011 YE40)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3591759',
#     'absolute_magnitude_h': 25.2,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0242412481,
#       'estimated_diameter_max': 0.0542050786},
#      'meters': {'estimated_diameter_min': 24.2412481101,
#       'estimated_diameter_max': 54.2050786336},
#      'miles': {'estimated_diameter_min': 0.0150628086,
#       'estimated_diameter_max': 0.0336814639},
#      'feet': {'estimated_diameter_min': 79.5316564495,
#       'estimated_diameter_max': 177.8381901842}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2020-01-01',
#       'close_approach_date_full': '2020-Jan-01 14:36',
#       'epoch_date_close_approach': 1577889360000,
#       'relative_velocity': {'kilometers_per_second': '12.7904463668',
#        'kilometers_per_hour': '46045.6069203144',
#        'miles_per_hour': '28610.949477792'},
#       'miss_distance': {'astronomical': '0.0643318776',
#        'lunar': '25.0251003864',
#        'kilometers': '9623911.862060712',
#        'miles': '5980021.5338013456'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3630817?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '3630817',
#     'neo_reference_id': '3630817',
#     'name': '(2013 EC20)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3630817',
#     'absolute_magnitude_h': 29.0,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0042126461,
#       'estimated_diameter_max': 0.0094197631},
#      'meters': {'estimated_diameter_min': 4.2126461056,
#       'estimated_diameter_max': 9.4197630572},
#      'miles': {'estimated_diameter_min': 0.0026176161,
#       'estimated_diameter_max': 0.0058531676},
#      'feet': {'estimated_diameter_min': 13.821017849,
#       'estimated_diameter_max': 30.9047354285}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2020-01-01',
#       'close_approach_date_full': '2020-Jan-01 03:31',
#       'epoch_date_close_approach': 1577849460000,
#       'relative_velocity': {'kilometers_per_second': '2.7933921715',
#        'kilometers_per_hour': '10056.2118173665',
#        'miles_per_hour': '6248.5389484075'},
#       'miss_distance': {'astronomical': '0.1620082804',
#        'lunar': '63.0212210756',
#        'kilometers': '24236093.670202748',
#        'miles': '15059610.2832560024'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3747497?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '3747497',
#     'neo_reference_id': '3747497',
#     'name': '(2016 EF195)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3747497',
#     'absolute_magnitude_h': 25.5,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0211132445,
#       'estimated_diameter_max': 0.0472106499},
#      'meters': {'estimated_diameter_min': 21.113244479,
#       'estimated_diameter_max': 47.2106498806},
#      'miles': {'estimated_diameter_min': 0.0131191578,
#       'estimated_diameter_max': 0.0293353287},
#      'feet': {'estimated_diameter_min': 69.2691770164,
#       'estimated_diameter_max': 154.8905885541}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2020-01-01',
#       'close_approach_date_full': '2020-Jan-01 05:50',
#       'epoch_date_close_approach': 1577857800000,
#       'relative_velocity': {'kilometers_per_second': '17.606764297',
#        'kilometers_per_hour': '63384.3514692871',
#        'miles_per_hour': '39384.5710560134'},
#       'miss_distance': {'astronomical': '0.2782185848',
#        'lunar': '108.2270294872',
#        'kilometers': '41620907.680494376',
#        'miles': '25862032.7942633488'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3564720?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '3564720',
#     'neo_reference_id': '3564720',
#     'name': '(2011 HS60)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3564720',
#     'absolute_magnitude_h': 21.3,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1460679643,
#       'estimated_diameter_max': 0.3266178974},
#      'meters': {'estimated_diameter_min': 146.0679642714,
#       'estimated_diameter_max': 326.6178974458},
#      'miles': {'estimated_diameter_min': 0.090762397,
#       'estimated_diameter_max': 0.2029508896},
#      'feet': {'estimated_diameter_min': 479.2256199,
#       'estimated_diameter_max': 1071.581062656}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2020-01-01',
#       'close_approach_date_full': '2020-Jan-01 21:59',
#       'epoch_date_close_approach': 1577915940000,
#       'relative_velocity': {'kilometers_per_second': '17.7744595857',
#        'kilometers_per_hour': '63988.054508511',
#        'miles_per_hour': '39759.6886472467'},
#       'miss_distance': {'astronomical': '0.1988786384',
#        'lunar': '77.3637903376',
#        'kilometers': '29751820.693140208',
#        'miles': '18486924.1286545504'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3976530?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '3976530',
#     'neo_reference_id': '3976530',
#     'name': '(2020 AM1)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3976530',
#     'absolute_magnitude_h': 24.7,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0305179233,
#       'estimated_diameter_max': 0.0682401509},
#      'meters': {'estimated_diameter_min': 30.5179232594,
#       'estimated_diameter_max': 68.2401509401},
#      'miles': {'estimated_diameter_min': 0.0189629525,
#       'estimated_diameter_max': 0.0424024508},
#      'feet': {'estimated_diameter_min': 100.1244233463,
#       'estimated_diameter_max': 223.8850168104}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2020-01-01',
#       'close_approach_date_full': '2020-Jan-01 07:18',
#       'epoch_date_close_approach': 1577863080000,
#       'relative_velocity': {'kilometers_per_second': '4.1529383168',
#        'kilometers_per_hour': '14950.577940303',
#        'miles_per_hour': '9289.70772074'},
#       'miss_distance': {'astronomical': '0.1596570278',
#        'lunar': '62.1065838142',
#        'kilometers': '23884351.289410786',
#        'miles': '14841047.7027134068'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3976542?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '3976542',
#     'neo_reference_id': '3976542',
#     'name': '(2020 AY1)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3976542',
#     'absolute_magnitude_h': 25.1,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0253837029,
#       'estimated_diameter_max': 0.0567596853},
#      'meters': {'estimated_diameter_min': 25.3837029364,
#       'estimated_diameter_max': 56.7596852866},
#      'miles': {'estimated_diameter_min': 0.0157726969,
#       'estimated_diameter_max': 0.0352688224},
#      'feet': {'estimated_diameter_min': 83.279867942,
#       'estimated_diameter_max': 186.2194458756}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2020-01-01',
#       'close_approach_date_full': '2020-Jan-01 00:54',
#       'epoch_date_close_approach': 1577840040000,
#       'relative_velocity': {'kilometers_per_second': '5.6220319555',
#        'kilometers_per_hour': '20239.3150398676',
#        'miles_per_hour': '12575.9232813'},
#       'miss_distance': {'astronomical': '0.0211660525',
#        'lunar': '8.2335944225',
#        'kilometers': '3166396.370308175',
#        'miles': '1967507.469975815'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3942362?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '3942362',
#     'neo_reference_id': '3942362',
#     'name': '(2019 YK)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3942362',
#     'absolute_magnitude_h': 24.0,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0421264611,
#       'estimated_diameter_max': 0.0941976306},
#      'meters': {'estimated_diameter_min': 42.1264610556,
#       'estimated_diameter_max': 94.1976305719},
#      'miles': {'estimated_diameter_min': 0.0261761612,
#       'estimated_diameter_max': 0.0585316759},
#      'feet': {'estimated_diameter_min': 138.2101784897,
#       'estimated_diameter_max': 309.0473542854}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2020-01-01',
#       'close_approach_date_full': '2020-Jan-01 02:06',
#       'epoch_date_close_approach': 1577844360000,
#       'relative_velocity': {'kilometers_per_second': '7.359263237',
#        'kilometers_per_hour': '26493.3476530253',
#        'miles_per_hour': '16461.9359347368'},
#       'miss_distance': {'astronomical': '0.036100967',
#        'lunar': '14.043276163',
#        'kilometers': '5400627.76814029',
#        'miles': '3355794.484864402'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3986685?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '3986685',
#     'neo_reference_id': '3986685',
#     'name': '(2020 AP3)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3986685',
#     'absolute_magnitude_h': 26.553,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.013000348,
#       'estimated_diameter_max': 0.0290696618},
#      'meters': {'estimated_diameter_min': 13.0003479619,
#       'estimated_diameter_max': 29.0696617739},
#      'miles': {'estimated_diameter_min': 0.0080780392,
#       'estimated_diameter_max': 0.0180630448},
#      'feet': {'estimated_diameter_min': 42.6520616072,
#       'estimated_diameter_max': 95.3729091343}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2020-01-01',
#       'close_approach_date_full': '2020-Jan-01 11:13',
#       'epoch_date_close_approach': 1577877180000,
#       'relative_velocity': {'kilometers_per_second': '5.1912515656',
#        'kilometers_per_hour': '18688.5056362591',
#        'miles_per_hour': '11612.3106271522'},
#       'miss_distance': {'astronomical': '0.0167404899',
#        'lunar': '6.5120505711',
#        'kilometers': '2504341.631796513',
#        'miles': '1556125.7314893594'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/54016975?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '54016975',
#     'neo_reference_id': '54016975',
#     'name': '(2020 JU)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54016975',
#     'absolute_magnitude_h': 21.051,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1638154943,
#       'estimated_diameter_max': 0.366302581},
#      'meters': {'estimated_diameter_min': 163.8154942984,
#       'estimated_diameter_max': 366.302581019},
#      'miles': {'estimated_diameter_min': 0.1017901975,
#       'estimated_diameter_max': 0.2276098011},
#      'feet': {'estimated_diameter_min': 537.452426314,
#       'estimated_diameter_max': 1201.7801599104}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2020-01-01',
#       'close_approach_date_full': '2020-Jan-01 20:45',
#       'epoch_date_close_approach': 1577911500000,
#       'relative_velocity': {'kilometers_per_second': '6.6517930219',
#        'kilometers_per_hour': '23946.4548788257',
#        'miles_per_hour': '14879.3958106792'},
#       'miss_distance': {'astronomical': '0.131171555',
#        'lunar': '51.025734895',
#        'kilometers': '19622985.23258785',
#        'miles': '12193157.61929833'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False}],
#   '2020-01-02': [{'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3971141?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '3971141',
#     'neo_reference_id': '3971141',
#     'name': '(2019 YO6)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3971141',
#     'absolute_magnitude_h': 22.2,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.096506147,
#       'estimated_diameter_max': 0.2157943048},
#      'meters': {'estimated_diameter_min': 96.5061469579,
#       'estimated_diameter_max': 215.7943048444},
#      'miles': {'estimated_diameter_min': 0.059966121,
#       'estimated_diameter_max': 0.134088323},
#      'feet': {'estimated_diameter_min': 316.6212271853,
#       'estimated_diameter_max': 707.9865871058}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2020-01-02',
#       'close_approach_date_full': '2020-Jan-02 10:02',
#       'epoch_date_close_approach': 1577959320000,
#       'relative_velocity': {'kilometers_per_second': '7.2172266296',
#        'kilometers_per_hour': '25982.0158667376',
#        'miles_per_hour': '16144.2142478626'},
#       'miss_distance': {'astronomical': '0.3130609556',
#        'lunar': '121.7807117284',
#        'kilometers': '46833252.137924572',
#        'miles': '29100833.4549282136'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3986810?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '3986810',
#     'neo_reference_id': '3986810',
#     'name': '(2020 BK2)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3986810',
#     'absolute_magnitude_h': 21.728,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1199374957,
#       'estimated_diameter_max': 0.2681883935},
#      'meters': {'estimated_diameter_min': 119.9374957269,
#       'estimated_diameter_max': 268.1883934965},
#      'miles': {'estimated_diameter_min': 0.0745256817,
#       'estimated_diameter_max': 0.1666444903},
#      'feet': {'estimated_diameter_min': 393.4957334807,
#       'estimated_diameter_max': 879.883208919}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2020-01-02',
#       'close_approach_date_full': '2020-Jan-02 04:59',
#       'epoch_date_close_approach': 1577941140000,
#       'relative_velocity': {'kilometers_per_second': '20.4292473629',
#        'kilometers_per_hour': '73545.2905063147',
#        'miles_per_hour': '45698.1834259932'},
#       'miss_distance': {'astronomical': '0.160088318',
#        'lunar': '62.274355702',
#        'kilometers': '23948871.38468266',
#        'miles': '14881138.630874308'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/2416591?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '2416591',
#     'neo_reference_id': '2416591',
#     'name': '416591 (2004 LC2)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2416591',
#     'absolute_magnitude_h': 18.5,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.5303407233,
#       'estimated_diameter_max': 1.1858779086},
#      'meters': {'estimated_diameter_min': 530.3407233187,
#       'estimated_diameter_max': 1185.8779085771},
#      'miles': {'estimated_diameter_min': 0.3295383456,
#       'estimated_diameter_max': 0.7368701419},
#      'feet': {'estimated_diameter_min': 1739.963058693,
#       'estimated_diameter_max': 3890.675677576}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2020-01-02',
#       'close_approach_date_full': '2020-Jan-02 01:53',
#       'epoch_date_close_approach': 1577929980000,
#       'relative_velocity': {'kilometers_per_second': '18.5987790232',
#        'kilometers_per_hour': '66955.6044836881',
#        'miles_per_hour': '41603.6087971005'},
#       'miss_distance': {'astronomical': '0.2049637326',
#        'lunar': '79.7308919814',
#        'kilometers': '30662137.824209562',
#        'miles': '19052568.9646014756'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3164418?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '3164418',
#     'neo_reference_id': '3164418',
#     'name': '(2003 UW29)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3164418',
#     'absolute_magnitude_h': 20.7,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1925550782,
#       'estimated_diameter_max': 0.4305662442},
#      'meters': {'estimated_diameter_min': 192.5550781879,
#       'estimated_diameter_max': 430.566244241},
#      'miles': {'estimated_diameter_min': 0.1196481415,
#       'estimated_diameter_max': 0.2675413778},
#      'feet': {'estimated_diameter_min': 631.7424027221,
#       'estimated_diameter_max': 1412.6189567557}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2020-01-02',
#       'close_approach_date_full': None,
#       'epoch_date_close_approach': 1577952000000,
#       'relative_velocity': {'kilometers_per_second': '37.622069405',
#        'kilometers_per_hour': '135439.449857996',
#        'miles_per_hour': '84156.807052042'},
#       'miss_distance': {'astronomical': '0.2527966887',
#        'lunar': '98.3379119043',
#        'kilometers': '37817846.172573069',
#        'miles': '23498919.9522395922'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3591616?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '3591616',
#     'neo_reference_id': '3591616',
#     'name': '(2011 YP10)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3591616',
#     'absolute_magnitude_h': 24.6,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0319561887,
#       'estimated_diameter_max': 0.0714562102},
#      'meters': {'estimated_diameter_min': 31.9561886721,
#       'estimated_diameter_max': 71.4562101727},
#      'miles': {'estimated_diameter_min': 0.0198566489,
#       'estimated_diameter_max': 0.0444008168},
#      'feet': {'estimated_diameter_min': 104.8431420431,
#       'estimated_diameter_max': 234.436392583}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2020-01-02',
#       'close_approach_date_full': '2020-Jan-02 08:37',
#       'epoch_date_close_approach': 1577954220000,
#       'relative_velocity': {'kilometers_per_second': '5.6815852767',
#        'kilometers_per_hour': '20453.7069959732',
#        'miles_per_hour': '12709.138105359'},
#       'miss_distance': {'astronomical': '0.0706734104',
#        'lunar': '27.4919566456',
#        'kilometers': '10572591.661475848',
#        'miles': '6569503.8265007824'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3599868?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '3599868',
#     'neo_reference_id': '3599868',
#     'name': '(2012 DN31)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3599868',
#     'absolute_magnitude_h': 24.0,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0421264611,
#       'estimated_diameter_max': 0.0941976306},
#      'meters': {'estimated_diameter_min': 42.1264610556,
#       'estimated_diameter_max': 94.1976305719},
#      'miles': {'estimated_diameter_min': 0.0261761612,
#       'estimated_diameter_max': 0.0585316759},
#      'feet': {'estimated_diameter_min': 138.2101784897,
#       'estimated_diameter_max': 309.0473542854}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2020-01-02',
#       'close_approach_date_full': '2020-Jan-02 13:13',
#       'epoch_date_close_approach': 1577970780000,
#       'relative_velocity': {'kilometers_per_second': '21.6163263712',
#        'kilometers_per_hour': '77818.7749363909',
#        'miles_per_hour': '48353.5604597813'},
#       'miss_distance': {'astronomical': '0.4554307051',
#        'lunar': '177.1625442839',
#        'kilometers': '68131463.415558137',
#        'miles': '42334928.2697188106'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3760885?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '3760885',
#     'neo_reference_id': '3760885',
#     'name': '(2016 TR55)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3760885',
#     'absolute_magnitude_h': 23.0,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0667659413,
#       'estimated_diameter_max': 0.1492931834},
#      'meters': {'estimated_diameter_min': 66.7659413495,
#       'estimated_diameter_max': 149.2931834393},
#      'miles': {'estimated_diameter_min': 0.0414864197,
#       'estimated_diameter_max': 0.0927664547},
#      'feet': {'estimated_diameter_min': 219.0483710172,
#       'estimated_diameter_max': 489.807047955}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2020-01-02',
#       'close_approach_date_full': '2020-Jan-02 15:10',
#       'epoch_date_close_approach': 1577977800000,
#       'relative_velocity': {'kilometers_per_second': '6.8351496237',
#        'kilometers_per_hour': '24606.538645157',
#        'miles_per_hour': '15289.5461931533'},
#       'miss_distance': {'astronomical': '0.4513546696',
#        'lunar': '175.5769664744',
#        'kilometers': '67521697.186713752',
#        'miles': '41956037.1045316976'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3736392?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '3736392',
#     'neo_reference_id': '3736392',
#     'name': '(2015 XZ168)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3736392',
#     'absolute_magnitude_h': 24.7,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0305179233,
#       'estimated_diameter_max': 0.0682401509},
#      'meters': {'estimated_diameter_min': 30.5179232594,
#       'estimated_diameter_max': 68.2401509401},
#      'miles': {'estimated_diameter_min': 0.0189629525,
#       'estimated_diameter_max': 0.0424024508},
#      'feet': {'estimated_diameter_min': 100.1244233463,
#       'estimated_diameter_max': 223.8850168104}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2020-01-02',
#       'close_approach_date_full': '2020-Jan-02 17:58',
#       'epoch_date_close_approach': 1577987880000,
#       'relative_velocity': {'kilometers_per_second': '9.066846587',
#        'kilometers_per_hour': '32640.6477133299',
#        'miles_per_hour': '20281.629130541'},
#       'miss_distance': {'astronomical': '0.4524349202',
#        'lunar': '175.9971839578',
#        'kilometers': '67683300.375539974',
#        'miles': '42056452.6697366812'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/2506491?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '2506491',
#     'neo_reference_id': '2506491',
#     'name': '506491 (2003 UW29)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2506491',
#     'absolute_magnitude_h': 20.6,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.2016299194,
#       'estimated_diameter_max': 0.4508582062},
#      'meters': {'estimated_diameter_min': 201.6299194428,
#       'estimated_diameter_max': 450.8582061718},
#      'miles': {'estimated_diameter_min': 0.1252869847,
#       'estimated_diameter_max': 0.2801502144},
#      'feet': {'estimated_diameter_min': 661.5155049046,
#       'estimated_diameter_max': 1479.1936371367}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2020-01-02',
#       'close_approach_date_full': '2020-Jan-02 09:35',
#       'epoch_date_close_approach': 1577957700000,
#       'relative_velocity': {'kilometers_per_second': '37.6220787455',
#        'kilometers_per_hour': '135439.4834837327',
#        'miles_per_hour': '84156.8279457671'},
#       'miss_distance': {'astronomical': '0.2527969538',
#        'lunar': '98.3380150282',
#        'kilometers': '37817885.830968406',
#        'miles': '23498944.5948237628'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3623681?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '3623681',
#     'neo_reference_id': '3623681',
#     'name': '(2013 AW52)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3623681',
#     'absolute_magnitude_h': 20.0,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.2658,
#       'estimated_diameter_max': 0.5943468684},
#      'meters': {'estimated_diameter_min': 265.8,
#       'estimated_diameter_max': 594.3468684194},
#      'miles': {'estimated_diameter_min': 0.1651604118,
#       'estimated_diameter_max': 0.369309908},
#      'feet': {'estimated_diameter_min': 872.047272,
#       'estimated_diameter_max': 1949.9569797852}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2020-01-02',
#       'close_approach_date_full': '2020-Jan-02 12:00',
#       'epoch_date_close_approach': 1577966400000,
#       'relative_velocity': {'kilometers_per_second': '16.5306202316',
#        'kilometers_per_hour': '59510.2328339112',
#        'miles_per_hour': '36977.34439616'},
#       'miss_distance': {'astronomical': '0.1826538865',
#        'lunar': '71.0523618485',
#        'kilometers': '27324632.367621755',
#        'miles': '16978739.238640019'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3837605?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '3837605',
#     'neo_reference_id': '3837605',
#     'name': '(2019 AE3)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3837605',
#     'absolute_magnitude_h': 27.4,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0088014652,
#       'estimated_diameter_max': 0.0196806745},
#      'meters': {'estimated_diameter_min': 8.801465209,
#       'estimated_diameter_max': 19.6806745089},
#      'miles': {'estimated_diameter_min': 0.0054689752,
#       'estimated_diameter_max': 0.0122290004},
#      'feet': {'estimated_diameter_min': 28.8761991163,
#       'estimated_diameter_max': 64.5691441559}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2020-01-02',
#       'close_approach_date_full': '2020-Jan-02 16:08',
#       'epoch_date_close_approach': 1577981280000,
#       'relative_velocity': {'kilometers_per_second': '8.2433461945',
#        'kilometers_per_hour': '29676.0463001893',
#        'miles_per_hour': '18439.5411024704'},
#       'miss_distance': {'astronomical': '0.0124617943',
#        'lunar': '4.8476379827',
#        'kilometers': '1864257.883658141',
#        'miles': '1158396.1333627058'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3711166?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '3711166',
#     'neo_reference_id': '3711166',
#     'name': '(2015 DY53)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3711166',
#     'absolute_magnitude_h': 21.3,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1460679643,
#       'estimated_diameter_max': 0.3266178974},
#      'meters': {'estimated_diameter_min': 146.0679642714,
#       'estimated_diameter_max': 326.6178974458},
#      'miles': {'estimated_diameter_min': 0.090762397,
#       'estimated_diameter_max': 0.2029508896},
#      'feet': {'estimated_diameter_min': 479.2256199,
#       'estimated_diameter_max': 1071.581062656}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2020-01-02',
#       'close_approach_date_full': '2020-Jan-02 14:40',
#       'epoch_date_close_approach': 1577976000000,
#       'relative_velocity': {'kilometers_per_second': '8.3858524056',
#        'kilometers_per_hour': '30189.0686602015',
#        'miles_per_hour': '18758.3132461124'},
#       'miss_distance': {'astronomical': '0.1934725122',
#        'lunar': '75.2608072458',
#        'kilometers': '28943075.728669014',
#        'miles': '17984393.3103958332'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3943370?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '3943370',
#     'neo_reference_id': '3943370',
#     'name': '(2019 YH2)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3943370',
#     'absolute_magnitude_h': 23.2,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0608912622,
#       'estimated_diameter_max': 0.1361570015},
#      'meters': {'estimated_diameter_min': 60.8912622106,
#       'estimated_diameter_max': 136.1570015386},
#      'miles': {'estimated_diameter_min': 0.0378360645,
#       'estimated_diameter_max': 0.0846040122},
#      'feet': {'estimated_diameter_min': 199.7744887109,
#       'estimated_diameter_max': 446.7093369279}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2020-01-02',
#       'close_approach_date_full': '2020-Jan-02 09:36',
#       'epoch_date_close_approach': 1577957760000,
#       'relative_velocity': {'kilometers_per_second': '14.298602757',
#        'kilometers_per_hour': '51474.9699252598',
#        'miles_per_hour': '31984.5445071704'},
#       'miss_distance': {'astronomical': '0.0189064392',
#        'lunar': '7.3546048488',
#        'kilometers': '2828363.033604504',
#        'miles': '1757463.2944259952'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3968763?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '3968763',
#     'neo_reference_id': '3968763',
#     'name': '(2020 AD)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3968763',
#     'absolute_magnitude_h': 27.2,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0096506147,
#       'estimated_diameter_max': 0.0215794305},
#      'meters': {'estimated_diameter_min': 9.6506146958,
#       'estimated_diameter_max': 21.5794304844},
#      'miles': {'estimated_diameter_min': 0.0059966121,
#       'estimated_diameter_max': 0.0134088323},
#      'feet': {'estimated_diameter_min': 31.6621227185,
#       'estimated_diameter_max': 70.7986587106}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2020-01-02',
#       'close_approach_date_full': '2020-Jan-02 09:12',
#       'epoch_date_close_approach': 1577956320000,
#       'relative_velocity': {'kilometers_per_second': '15.6228249368',
#        'kilometers_per_hour': '56242.1697723763',
#        'miles_per_hour': '34946.6971010635'},
#       'miss_distance': {'astronomical': '0.0059823159',
#        'lunar': '2.3271208851',
#        'kilometers': '894941.716307133',
#        'miles': '556090.9962311154'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3968762?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '3968762',
#     'neo_reference_id': '3968762',
#     'name': '(2020 AC)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3968762',
#     'absolute_magnitude_h': 26.7,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0121494041,
#       'estimated_diameter_max': 0.0271668934},
#      'meters': {'estimated_diameter_min': 12.14940408,
#       'estimated_diameter_max': 27.1668934089},
#      'miles': {'estimated_diameter_min': 0.0075492874,
#       'estimated_diameter_max': 0.0168807197},
#      'feet': {'estimated_diameter_min': 39.8602508817,
#       'estimated_diameter_max': 89.1302305717}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2020-01-02',
#       'close_approach_date_full': '2020-Jan-02 06:56',
#       'epoch_date_close_approach': 1577948160000,
#       'relative_velocity': {'kilometers_per_second': '5.7931991443',
#        'kilometers_per_hour': '20855.5169195679',
#        'miles_per_hour': '12958.8071659393'},
#       'miss_distance': {'astronomical': '0.008656724',
#        'lunar': '3.367465636',
#        'kilometers': '1295027.47157788',
#        'miles': '804692.756739544'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3989098?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '3989098',
#     'neo_reference_id': '3989098',
#     'name': '(2020 BS5)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3989098',
#     'absolute_magnitude_h': 23.053,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0651560843,
#       'estimated_diameter_max': 0.1456934337},
#      'meters': {'estimated_diameter_min': 65.156084312,
#       'estimated_diameter_max': 145.6934336694},
#      'miles': {'estimated_diameter_min': 0.0404861013,
#       'estimated_diameter_max': 0.0905296746},
#      'feet': {'estimated_diameter_min': 213.7666876543,
#       'estimated_diameter_max': 477.9968449199}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2020-01-02',
#       'close_approach_date_full': '2020-Jan-02 06:20',
#       'epoch_date_close_approach': 1577946000000,
#       'relative_velocity': {'kilometers_per_second': '2.1532692473',
#        'kilometers_per_hour': '7751.7692902593',
#        'miles_per_hour': '4816.6479792725'},
#       'miss_distance': {'astronomical': '0.2246933051',
#        'lunar': '87.4056956839',
#        'kilometers': '33613639.846220137',
#        'miles': '20886547.2783744106'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3973542?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '3973542',
#     'neo_reference_id': '3973542',
#     'name': '(2020 AC1)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3973542',
#     'absolute_magnitude_h': 28.4,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0055533491,
#       'estimated_diameter_max': 0.0124176661},
#      'meters': {'estimated_diameter_min': 5.5533491158,
#       'estimated_diameter_max': 12.4176661257},
#      'miles': {'estimated_diameter_min': 0.0034506901,
#       'estimated_diameter_max': 0.0077159776},
#      'feet': {'estimated_diameter_min': 18.2196499131,
#       'estimated_diameter_max': 40.740375732}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2020-01-02',
#       'close_approach_date_full': '2020-Jan-02 22:50',
#       'epoch_date_close_approach': 1578005400000,
#       'relative_velocity': {'kilometers_per_second': '6.2257348203',
#        'kilometers_per_hour': '22412.6453529055',
#        'miles_per_hour': '13926.3462194206'},
#       'miss_distance': {'astronomical': '0.0053331709',
#        'lunar': '2.0746034801',
#        'kilometers': '797831.006985983',
#        'miles': '495749.1995452454'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3976533?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '3976533',
#     'neo_reference_id': '3976533',
#     'name': '(2020 AP1)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3976533',
#     'absolute_magnitude_h': 29.6,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0031956189,
#       'estimated_diameter_max': 0.007145621},
#      'meters': {'estimated_diameter_min': 3.1956188672,
#       'estimated_diameter_max': 7.1456210173},
#      'miles': {'estimated_diameter_min': 0.0019856649,
#       'estimated_diameter_max': 0.0044400817},
#      'feet': {'estimated_diameter_min': 10.4843142043,
#       'estimated_diameter_max': 23.4436392583}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2020-01-02',
#       'close_approach_date_full': '2020-Jan-02 15:33',
#       'epoch_date_close_approach': 1577979180000,
#       'relative_velocity': {'kilometers_per_second': '5.6085426073',
#        'kilometers_per_hour': '20190.7533862414',
#        'miles_per_hour': '12545.7489582454'},
#       'miss_distance': {'astronomical': '0.0021847307',
#        'lunar': '0.8498602423',
#        'kilometers': '326831.059243609',
#        'miles': '203083.4031114442'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3971137?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '3971137',
#     'neo_reference_id': '3971137',
#     'name': '(2019 YL6)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3971137',
#     'absolute_magnitude_h': 25.3,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0231502122,
#       'estimated_diameter_max': 0.0517654482},
#      'meters': {'estimated_diameter_min': 23.150212221,
#       'estimated_diameter_max': 51.7654482198},
#      'miles': {'estimated_diameter_min': 0.0143848705,
#       'estimated_diameter_max': 0.0321655483},
#      'feet': {'estimated_diameter_min': 75.9521422633,
#       'estimated_diameter_max': 169.8341531374}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2020-01-02',
#       'close_approach_date_full': '2020-Jan-02 07:47',
#       'epoch_date_close_approach': 1577951220000,
#       'relative_velocity': {'kilometers_per_second': '4.8040269454',
#        'kilometers_per_hour': '17294.4970035227',
#        'miles_per_hour': '10746.1278742166'},
#       'miss_distance': {'astronomical': '0.0510719339',
#        'lunar': '19.8669822871',
#        'kilometers': '7640252.528220793',
#        'miles': '4747432.7796532234'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False}],
#   '2020-01-03': [{'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3989183?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '3989183',
#     'neo_reference_id': '3989183',
#     'name': '(2020 BD8)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3989183',
#     'absolute_magnitude_h': 20.846,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1800341848,
#       'estimated_diameter_max': 0.4025686755},
#      'meters': {'estimated_diameter_min': 180.0341848235,
#       'estimated_diameter_max': 402.5686755391},
#      'miles': {'estimated_diameter_min': 0.1118680215,
#       'estimated_diameter_max': 0.2501445005},
#      'feet': {'estimated_diameter_min': 590.6633549363,
#       'estimated_diameter_max': 1320.7634134556}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2020-01-03',
#       'close_approach_date_full': '2020-Jan-03 09:11',
#       'epoch_date_close_approach': 1578042660000,
#       'relative_velocity': {'kilometers_per_second': '28.3289968243',
#        'kilometers_per_hour': '101984.3885673511',
#        'miles_per_hour': '63369.1329961966'},
#       'miss_distance': {'astronomical': '0.3713311346',
#        'lunar': '144.4478113594',
#        'kilometers': '55550346.800843302',
#        'miles': '34517384.9096374876'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3989261?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '3989261',
#     'neo_reference_id': '3989261',
#     'name': '(2020 BN11)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3989261',
#     'absolute_magnitude_h': 22.775,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0740551007,
#       'estimated_diameter_max': 0.1655922392},
#      'meters': {'estimated_diameter_min': 74.0551006622,
#       'estimated_diameter_max': 165.5922391612},
#      'miles': {'estimated_diameter_min': 0.046015692,
#       'estimated_diameter_max': 0.1028942152},
#      'feet': {'estimated_diameter_min': 242.9629364565,
#       'estimated_diameter_max': 543.2816419297}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2020-01-03',
#       'close_approach_date_full': '2020-Jan-03 15:37',
#       'epoch_date_close_approach': 1578065820000,
#       'relative_velocity': {'kilometers_per_second': '19.8574199477',
#        'kilometers_per_hour': '71486.7118117636',
#        'miles_per_hour': '44419.0626810372'},
#       'miss_distance': {'astronomical': '0.2500351411',
#        'lunar': '97.2636698879',
#        'kilometers': '37404724.533709457',
#        'miles': '23242218.0692742266'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3623610?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '3623610',
#     'neo_reference_id': '3623610',
#     'name': '(2013 AB32)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3623610',
#     'absolute_magnitude_h': 22.9,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0699125232,
#       'estimated_diameter_max': 0.1563291544},
#      'meters': {'estimated_diameter_min': 69.9125232246,
#       'estimated_diameter_max': 156.3291544087},
#      'miles': {'estimated_diameter_min': 0.0434416145,
#       'estimated_diameter_max': 0.097138403},
#      'feet': {'estimated_diameter_min': 229.3718026961,
#       'estimated_diameter_max': 512.8909429502}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2020-01-03',
#       'close_approach_date_full': '2020-Jan-03 07:27',
#       'epoch_date_close_approach': 1578036420000,
# ...
#       'estimated_diameter_max': 187.430377019},
#      'miles': {'estimated_diameter_min': 0.0520841951,
#       'estimated_diameter_max': 0.1164638008},
#      'feet': {'estimated_diameter_min': 275.004644012,
#       'estimated_diameter_max': 614.9290781389}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2020-01-07',
#       'close_approach_date_full': '2020-Jan-07 05:47',
#       'epoch_date_close_approach': 1578376020000,
#       'relative_velocity': {'kilometers_per_second': '9.9349804405',
#        'kilometers_per_hour': '35765.929585732',
#        'miles_per_hour': '22223.5577473122'},
#       'miss_distance': {'astronomical': '0.122736413',
#        'lunar': '47.744464657',
#        'kilometers': '18361105.95624031',
#        'miles': '11409062.195963878'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/2481442?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '2481442',
#     'neo_reference_id': '2481442',
#     'name': '481442 (2006 WO3)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2481442',
#     'absolute_magnitude_h': 21.6,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1272198785,
#       'estimated_diameter_max': 0.2844722965},
#      'meters': {'estimated_diameter_min': 127.2198785394,
#       'estimated_diameter_max': 284.4722965033},
#      'miles': {'estimated_diameter_min': 0.0790507431,
#       'estimated_diameter_max': 0.1767628354},
#      'feet': {'estimated_diameter_min': 417.3880663071,
#       'estimated_diameter_max': 933.3080892598}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2020-01-07',
#       'close_approach_date_full': '2020-Jan-07 06:35',
#       'epoch_date_close_approach': 1578378900000,
#       'relative_velocity': {'kilometers_per_second': '22.7517778204',
#        'kilometers_per_hour': '81906.4001532924',
#        'miles_per_hour': '50893.451806361'},
#       'miss_distance': {'astronomical': '0.4152303795',
#        'lunar': '161.5246176255',
#        'kilometers': '62117580.332491665',
#        'miles': '38598074.602108377'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/2512244?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '2512244',
#     'neo_reference_id': '2512244',
#     'name': '512244 (2015 YE18)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2512244',
#     'absolute_magnitude_h': 17.8,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.7320739893,
#       'estimated_diameter_max': 1.6369672047},
#      'meters': {'estimated_diameter_min': 732.0739893473,
#       'estimated_diameter_max': 1636.96720474},
#      'miles': {'estimated_diameter_min': 0.4548895468,
#       'estimated_diameter_max': 1.017163949},
#      'feet': {'estimated_diameter_min': 2401.8176272101,
#       'estimated_diameter_max': 5370.6274839991}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2020-01-07',
#       'close_approach_date_full': '2020-Jan-07 20:08',
#       'epoch_date_close_approach': 1578427680000,
#       'relative_velocity': {'kilometers_per_second': '34.7839664276',
#        'kilometers_per_hour': '125222.2791392326',
#        'miles_per_hour': '77808.2545018193'},
#       'miss_distance': {'astronomical': '0.4319452385',
#        'lunar': '168.0266977765',
#        'kilometers': '64618087.636241995',
#        'miles': '40151817.792629731'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/2281365?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '2281365',
#     'neo_reference_id': '2281365',
#     'name': '281365 (2008 CM116)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2281365',
#     'absolute_magnitude_h': 17.4,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.8801465209,
#       'estimated_diameter_max': 1.9680674509},
#      'meters': {'estimated_diameter_min': 880.1465209007,
#       'estimated_diameter_max': 1968.067450894},
#      'miles': {'estimated_diameter_min': 0.5468975238,
#       'estimated_diameter_max': 1.22290004},
#      'feet': {'estimated_diameter_min': 2887.6199116319,
#       'estimated_diameter_max': 6456.914415591}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2020-01-07',
#       'close_approach_date_full': '2020-Jan-07 22:04',
#       'epoch_date_close_approach': 1578434640000,
#       'relative_velocity': {'kilometers_per_second': '30.5425492482',
#        'kilometers_per_hour': '109953.1772933486',
#        'miles_per_hour': '68320.6284131921'},
#       'miss_distance': {'astronomical': '0.4485551327',
#        'lunar': '174.4879466203',
#        'kilometers': '67102892.429487349',
#        'miles': '41695803.8955654562'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3703545?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '3703545',
#     'neo_reference_id': '3703545',
#     'name': '(2015 AJ44)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3703545',
#     'absolute_magnitude_h': 22.3,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0921626549,
#       'estimated_diameter_max': 0.2060819612},
#      'meters': {'estimated_diameter_min': 92.1626548503,
#       'estimated_diameter_max': 206.0819612321},
#      'miles': {'estimated_diameter_min': 0.057267201,
#       'estimated_diameter_max': 0.1280533543},
#      'feet': {'estimated_diameter_min': 302.370924539,
#       'estimated_diameter_max': 676.1219416887}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2020-01-07',
#       'close_approach_date_full': '2020-Jan-07 20:12',
#       'epoch_date_close_approach': 1578427920000,
#       'relative_velocity': {'kilometers_per_second': '11.2207604251',
#        'kilometers_per_hour': '40394.7375301883',
#        'miles_per_hour': '25099.7189947995'},
#       'miss_distance': {'astronomical': '0.2813200245',
#        'lunar': '109.4334895305',
#        'kilometers': '42084876.453547815',
#        'miles': '26150329.621337247'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3626689?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '3626689',
#     'neo_reference_id': '3626689',
#     'name': '(2013 CA88)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3626689',
#     'absolute_magnitude_h': 24.8,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0291443905,
#       'estimated_diameter_max': 0.0651688382},
#      'meters': {'estimated_diameter_min': 29.1443904535,
#       'estimated_diameter_max': 65.1688382168},
#      'miles': {'estimated_diameter_min': 0.018109479,
#       'estimated_diameter_max': 0.0404940262},
#      'feet': {'estimated_diameter_min': 95.6180819754,
#       'estimated_diameter_max': 213.8085311752}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2020-01-07',
#       'close_approach_date_full': '2020-Jan-07 19:33',
#       'epoch_date_close_approach': 1578425580000,
#       'relative_velocity': {'kilometers_per_second': '3.3977532517',
#        'kilometers_per_hour': '12231.9117059549',
#        'miles_per_hour': '7600.4342486251'},
#       'miss_distance': {'astronomical': '0.0715799299',
#        'lunar': '27.8445927311',
#        'kilometers': '10708205.047789313',
#        'miles': '6653770.0772779994'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3841977?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '3841977',
#     'neo_reference_id': '3841977',
#     'name': '(2019 KW)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3841977',
#     'absolute_magnitude_h': 26.9,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0110803882,
#       'estimated_diameter_max': 0.0247765013},
#      'meters': {'estimated_diameter_min': 11.0803882126,
#       'estimated_diameter_max': 24.7765012606},
#      'miles': {'estimated_diameter_min': 0.0068850319,
#       'estimated_diameter_max': 0.0153953994},
#      'feet': {'estimated_diameter_min': 36.3529808636,
#       'estimated_diameter_max': 81.2877363957}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2020-01-07',
#       'close_approach_date_full': '2020-Jan-07 04:33',
#       'epoch_date_close_approach': 1578371580000,
#       'relative_velocity': {'kilometers_per_second': '8.9089931328',
#        'kilometers_per_hour': '32072.3752781005',
#        'miles_per_hour': '19928.5267387731'},
#       'miss_distance': {'astronomical': '0.2695802831',
#        'lunar': '104.8667301259',
#        'kilometers': '40328636.145756997',
#        'miles': '25059052.4972686786'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3893768?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '3893768',
#     'neo_reference_id': '3893768',
#     'name': '(2019 WH6)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3893768',
#     'absolute_magnitude_h': 18.8,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.4619074603,
#       'estimated_diameter_max': 1.0328564805},
#      'meters': {'estimated_diameter_min': 461.9074602816,
#       'estimated_diameter_max': 1032.8564805039},
#      'miles': {'estimated_diameter_min': 0.2870159005,
#       'estimated_diameter_max': 0.6417870641},
#      'feet': {'estimated_diameter_min': 1515.4444719902,
#       'estimated_diameter_max': 3388.6368554964}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2020-01-07',
#       'close_approach_date_full': '2020-Jan-07 14:26',
#       'epoch_date_close_approach': 1578407160000,
#       'relative_velocity': {'kilometers_per_second': '32.2682535309',
#        'kilometers_per_hour': '116165.7127113599',
#        'miles_per_hour': '72180.8563233447'},
#       'miss_distance': {'astronomical': '0.2180335554',
#        'lunar': '84.8150530506',
#        'kilometers': '32617355.476366998',
#        'miles': '20267484.8772526524'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3973548?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '3973548',
#     'neo_reference_id': '3973548',
#     'name': '(2020 AJ1)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3973548',
#     'absolute_magnitude_h': 23.3,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.058150704,
#       'estimated_diameter_max': 0.130028927},
#      'meters': {'estimated_diameter_min': 58.1507039646,
#       'estimated_diameter_max': 130.0289270043},
#      'miles': {'estimated_diameter_min': 0.0361331611,
#       'estimated_diameter_max': 0.0807962044},
#      'feet': {'estimated_diameter_min': 190.7831555951,
#       'estimated_diameter_max': 426.6041048727}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2020-01-07',
#       'close_approach_date_full': '2020-Jan-07 15:00',
#       'epoch_date_close_approach': 1578409200000,
#       'relative_velocity': {'kilometers_per_second': '22.16609708',
#        'kilometers_per_hour': '79797.9494878484',
#        'miles_per_hour': '49583.3425581578'},
#       'miss_distance': {'astronomical': '0.0346991631',
#        'lunar': '13.4979744459',
#        'kilometers': '5190920.890542597',
#        'miles': '3225488.6734859586'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3976539?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '3976539',
#     'neo_reference_id': '3976539',
#     'name': '(2020 AV1)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3976539',
#     'absolute_magnitude_h': 26.0,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0167708462,
#       'estimated_diameter_max': 0.0375007522},
#      'meters': {'estimated_diameter_min': 16.7708462163,
#       'estimated_diameter_max': 37.5007521798},
#      'miles': {'estimated_diameter_min': 0.0104209175,
#       'estimated_diameter_max': 0.0233018799},
#      'feet': {'estimated_diameter_min': 55.0224631002,
#       'estimated_diameter_max': 123.0339677816}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2020-01-07',
#       'close_approach_date_full': '2020-Jan-07 07:46',
#       'epoch_date_close_approach': 1578383160000,
#       'relative_velocity': {'kilometers_per_second': '12.0924879022',
#        'kilometers_per_hour': '43532.9564477969',
#        'miles_per_hour': '27049.6861883547'},
#       'miss_distance': {'astronomical': '0.0186063516',
#        'lunar': '7.2378707724',
#        'kilometers': '2783470.567831092',
#        'miles': '1729568.4096973896'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3986636?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '3986636',
#     'neo_reference_id': '3986636',
#     'name': '(2020 AD3)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3986636',
#     'absolute_magnitude_h': 21.7,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.1214940408,
#       'estimated_diameter_max': 0.2716689341},
#      'meters': {'estimated_diameter_min': 121.4940407996,
#       'estimated_diameter_max': 271.6689340891},
#      'miles': {'estimated_diameter_min': 0.0754928736,
#       'estimated_diameter_max': 0.1688071972},
#      'feet': {'estimated_diameter_min': 398.6025088171,
#       'estimated_diameter_max': 891.3023057169}},
#     'is_potentially_hazardous_asteroid': True,
#     'close_approach_data': [{'close_approach_date': '2020-01-07',
#       'close_approach_date_full': '2020-Jan-07 18:45',
#       'epoch_date_close_approach': 1578422700000,
#       'relative_velocity': {'kilometers_per_second': '16.4090673576',
#        'kilometers_per_hour': '59072.642487283',
#        'miles_per_hour': '36705.4427721676'},
#       'miss_distance': {'astronomical': '0.0858393146',
#        'lunar': '33.3914933794',
#        'kilometers': '12841378.626419902',
#        'miles': '7979262.6751305676'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False},
#    {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3893726?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'},
#     'id': '3893726',
#     'neo_reference_id': '3893726',
#     'name': '(2019 WV4)',
#     'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3893726',
#     'absolute_magnitude_h': 23.5,
#     'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0530340723,
#       'estimated_diameter_max': 0.1185877909},
#      'meters': {'estimated_diameter_min': 53.0340723319,
#       'estimated_diameter_max': 118.5877908577},
#      'miles': {'estimated_diameter_min': 0.0329538346,
#       'estimated_diameter_max': 0.0736870142},
#      'feet': {'estimated_diameter_min': 173.9963058693,
#       'estimated_diameter_max': 389.0675677576}},
#     'is_potentially_hazardous_asteroid': False,
#     'close_approach_data': [{'close_approach_date': '2020-01-07',
#       'close_approach_date_full': '2020-Jan-07 11:30',
#       'epoch_date_close_approach': 1578396600000,
#       'relative_velocity': {'kilometers_per_second': '7.956450606',
#        'kilometers_per_hour': '28643.222181446',
#        'miles_per_hour': '17797.7843604657'},
#       'miss_distance': {'astronomical': '0.1023551005',
#        'lunar': '39.8161340945',
#        'kilometers': '15312105.018435935',
#        'miles': '9514500.865188503'},
#       'orbiting_body': 'Earth'}],
#     'is_sentry_object': False}]}}

# %%
# select the near_earth_objects key

neo_json = (r_json['near_earth_objects'])

# %%
print(neo_json)
# Out:
# {'2020-01-01': [{'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3978225?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'}, 'id': '3978225', 'neo_reference_id': '3978225', 'name': '(2020 AN2)', 'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3978225', 'absolute_magnitude_h': 26.5, 'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0133215567, 'estimated_diameter_max': 0.0297879063}, 'meters': {'estimated_diameter_min': 13.3215566698, 'estimated_diameter_max': 29.7879062798}, 'miles': {'estimated_diameter_min': 0.008277629, 'estimated_diameter_max': 0.0185093411}, 'feet': {'estimated_diameter_min': 43.7058959846, 'estimated_diameter_max': 97.7293544391}}, 'is_potentially_hazardous_asteroid': False, 'close_approach_data': [{'close_approach_date': '2020-01-01', 'close_approach_date_full': '2020-Jan-01 21:18', 'epoch_date_close_approach': 1577913480000, 'relative_velocity': {'kilometers_per_second': '15.3528156363', 'kilometers_per_hour': '55270.1362905576', 'miles_per_hour': '34342.7132967634'}, 'miss_distance': {'astronomical': '0.0202143162', 'lunar': '7.8633690018', 'kilometers': '3024018.647026494', 'miles': '1879038.0551098572'}, 'orbiting_body': 'Earth'}], 'is_sentry_object': False}, {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3972421?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'}, 'id': '3972421', 'neo_reference_id': '3972421', 'name': '(2020 AX)', 'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3972421', 'absolute_magnitude_h': 26.3, 'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0146067964, 'estimated_diameter_max': 0.0326617897}, 'meters': {'estimated_diameter_min': 14.6067964271, 'estimated_diameter_max': 32.6617897446}, 'miles': {'estimated_diameter_min': 0.0090762397, 'estimated_diameter_max': 0.020295089}, 'feet': {'estimated_diameter_min': 47.92256199, 'estimated_diameter_max': 107.1581062656}}, 'is_potentially_hazardous_asteroid': False, 'close_approach_data': [{'close_approach_date': '2020-01-01', 'close_approach_date_full': '2020-Jan-01 22:49', 'epoch_date_close_approach': 1577918940000, 'relative_velocity': {'kilometers_per_second': '7.3167354067', 'kilometers_per_hour': '26340.2474640716', 'miles_per_hour': '16366.8054312171'}, 'miss_distance': {'astronomical': '0.049656182', 'lunar': '19.316254798', 'kilometers': '7428459.05953234', 'miles': '4615830.420692692'}, 'orbiting_body': 'Earth'}], 'is_sentry_object': False}, {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3893737?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'}, 'id': '3893737', 'neo_reference_id': '3893737', 'name': '(2019 WE5)', 'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3893737', 'absolute_magnitude_h': 23.0, 'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0667659413, 'estimated_diameter_max': 0.1492931834}, 'meters': {'estimated_diameter_min': 66.7659413495, 'estimated_diameter_max': 149.2931834393}, 'miles': {'estimated_diameter_min': 0.0414864197, 'estimated_diameter_max': 0.0927664547}, 'feet': {'estimated_diameter_min': 219.0483710172, 'estimated_diameter_max': 489.807047955}}, 'is_potentially_hazardous_asteroid': False, 'close_approach_data': [{'close_approach_date': '2020-01-01', 'close_approach_date_full': '2020-Jan-01 14:55', 'epoch_date_close_approach': 1577890500000, 'relative_velocity': {'kilometers_per_second': '5.0028249279', 'kilometers_per_hour': '18010.1697403975', 'miles_per_hour': '11190.8190811931'}, 'miss_distance': {'astronomical': '0.1345974227', 'lunar': '52.3583974303', 'kilometers': '20135487.743409649', 'miles': '12511611.9126011962'}, 'orbiting_body': 'Earth'}], 'is_sentry_object': False}, {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3976578?api_key=byNNNtQ89WYEBDzIKuZ99ng9jeYNaM4PygnfpbeV'}, 'id': '3976578', 'neo_reference_id': '3976578', 'name': '(2020 AE2)', 'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3976578', 'absolute_magnitude_h': 22.9, 'estimated_diameter': {'kilometers': {'estim ...

# %%
neo_json.keys()
# Out:
# dict_keys(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04', '2020-01-05', '2020-01-06', '2020-01-07'])

# %%
# create dataframe for each key/date

one = pd.DataFrame(neo_json['2020-01-01'])
two = pd.DataFrame(neo_json['2020-01-02'])
three = pd.DataFrame(neo_json['2020-01-03'])
four = pd.DataFrame(neo_json['2020-01-04'])
five = pd.DataFrame(neo_json['2020-01-05'])
six = pd.DataFrame(neo_json['2020-01-06'])
seven = pd.DataFrame(neo_json['2020-01-07'])

# %%
df_list = [one, two, three, four, five, six, seven]

# %%
# concat each dataframe for all dates from list

neo_df = pd.concat(df_list)

# %%
neo_df
# Out:
#                                                 links       id  \
# 0   {'self': 'http://www.neowsapp.com/rest/v1/neo/...  3978225
# 1   {'self': 'http://www.neowsapp.com/rest/v1/neo/...  3972421
# 2   {'self': 'http://www.neowsapp.com/rest/v1/neo/...  3893737
# 3   {'self': 'http://www.neowsapp.com/rest/v1/neo/...  3976578
# 4   {'self': 'http://www.neowsapp.com/rest/v1/neo/...  3591759
# ..                                                ...      ...
# 19  {'self': 'http://www.neowsapp.com/rest/v1/neo/...  3893768
# 20  {'self': 'http://www.neowsapp.com/rest/v1/neo/...  3973548
# 21  {'self': 'http://www.neowsapp.com/rest/v1/neo/...  3976539
# 22  {'self': 'http://www.neowsapp.com/rest/v1/neo/...  3986636
# 23  {'self': 'http://www.neowsapp.com/rest/v1/neo/...  3893726
#
#    neo_reference_id         name  \
# 0           3978225   (2020 AN2)
# 1           3972421    (2020 AX)
# 2           3893737   (2019 WE5)
# 3           3976578   (2020 AE2)
# 4           3591759  (2011 YE40)
# ..              ...          ...
# 19          3893768   (2019 WH6)
# 20          3973548   (2020 AJ1)
# 21          3976539   (2020 AV1)
# 22          3986636   (2020 AD3)
# 23          3893726   (2019 WV4)
#
#                                      nasa_jpl_url  absolute_magnitude_h  \
# 0   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3978225                  26.5
# 1   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3972421                  26.3
# 2   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3893737                  23.0
# 3   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3976578                  22.9
# 4   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3591759                  25.2
# ..                                            ...                   ...
# 19  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3893768                  18.8
# 20  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3973548                  23.3
# 21  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3976539                  26.0
# 22  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3986636                  21.7
# 23  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3893726                  23.5
#
#                                    estimated_diameter  \
# 0   {'kilometers': {'estimated_diameter_min': 0.01...
# 1   {'kilometers': {'estimated_diameter_min': 0.01...
# 2   {'kilometers': {'estimated_diameter_min': 0.06...
# 3   {'kilometers': {'estimated_diameter_min': 0.06...
# 4   {'kilometers': {'estimated_diameter_min': 0.02...
# ..                                                ...
# 19  {'kilometers': {'estimated_diameter_min': 0.46...
# 20  {'kilometers': {'estimated_diameter_min': 0.05...
# 21  {'kilometers': {'estimated_diameter_min': 0.01...
# 22  {'kilometers': {'estimated_diameter_min': 0.12...
# 23  {'kilometers': {'estimated_diameter_min': 0.05...
#
#     is_potentially_hazardous_asteroid  \
# 0                               False
# 1                               False
# 2                               False
# 3                               False
# 4                               False
# ..                                ...
# 19                              False
# 20                              False
# 21                              False
# 22                               True
# 23                              False
#
#                                   close_approach_data  is_sentry_object
# 0   [{'close_approach_date': '2020-01-01', 'close_...             False
# 1   [{'close_approach_date': '2020-01-01', 'close_...             False
# 2   [{'close_approach_date': '2020-01-01', 'close_...             False
# 3   [{'close_approach_date': '2020-01-01', 'close_...             False
# 4   [{'close_approach_date': '2020-01-01', 'close_...             False
# ..                                                ...               ...
# 19  [{'close_approach_date': '2020-01-07', 'close_...             False
# 20  [{'close_approach_date': '2020-01-07', 'close_...             False
# 21  [{'close_approach_date': '2020-01-07', 'close_...             False
# 22  [{'close_approach_date': '2020-01-07', 'close_...             False
# 23  [{'close_approach_date': '2020-01-07', 'close_...             False
#
# [105 rows x 10 columns]

# %%
neo_df.shape
# Out:
# (105, 10)

# %% [markdown]
# ### 1. Unpack Dictionary

# %% [markdown]
# There are several columns with dictionaries in them. Close_approach_data is what I am interested in. This column of dictionaries will be unpacked into their separate columns. There are further dictionaries within that dictionary.

# %%
# apply pd.Series to close_approach_data column

tmp = neo_df['close_approach_data'].apply(pd.Series)

# %%
tmp.rename(columns = {0: 'close_approach_data'}, inplace=True)

# %%
tmp
# Out:
#                                   close_approach_data
# 0   {'close_approach_date': '2020-01-01', 'close_a...
# 1   {'close_approach_date': '2020-01-01', 'close_a...
# 2   {'close_approach_date': '2020-01-01', 'close_a...
# 3   {'close_approach_date': '2020-01-01', 'close_a...
# 4   {'close_approach_date': '2020-01-01', 'close_a...
# ..                                                ...
# 19  {'close_approach_date': '2020-01-07', 'close_a...
# 20  {'close_approach_date': '2020-01-07', 'close_a...
# 21  {'close_approach_date': '2020-01-07', 'close_a...
# 22  {'close_approach_date': '2020-01-07', 'close_a...
# 23  {'close_approach_date': '2020-01-07', 'close_a...
#
# [105 rows x 1 columns]

# %%
# apply pd.Series to close_approach_data column

close_data = tmp['close_approach_data'].apply(pd.Series)

# %%
close_data
# Out:
#    close_approach_date close_approach_date_full  epoch_date_close_approach  \
# 0           2020-01-01        2020-Jan-01 21:18              1577913480000
# 1           2020-01-01        2020-Jan-01 22:49              1577918940000
# 2           2020-01-01        2020-Jan-01 14:55              1577890500000
# 3           2020-01-01        2020-Jan-01 15:16              1577891760000
# 4           2020-01-01        2020-Jan-01 14:36              1577889360000
# ..                 ...                      ...                        ...
# 19          2020-01-07        2020-Jan-07 14:26              1578407160000
# 20          2020-01-07        2020-Jan-07 15:00              1578409200000
# 21          2020-01-07        2020-Jan-07 07:46              1578383160000
# 22          2020-01-07        2020-Jan-07 18:45              1578422700000
# 23          2020-01-07        2020-Jan-07 11:30              1578396600000
#
#                                     relative_velocity  \
# 0   {'kilometers_per_second': '15.3528156363', 'ki...
# 1   {'kilometers_per_second': '7.3167354067', 'kil...
# 2   {'kilometers_per_second': '5.0028249279', 'kil...
# 3   {'kilometers_per_second': '13.2987974369', 'ki...
# 4   {'kilometers_per_second': '12.7904463668', 'ki...
# ..                                                ...
# 19  {'kilometers_per_second': '32.2682535309', 'ki...
# 20  {'kilometers_per_second': '22.16609708', 'kilo...
# 21  {'kilometers_per_second': '12.0924879022', 'ki...
# 22  {'kilometers_per_second': '16.4090673576', 'ki...
# 23  {'kilometers_per_second': '7.956450606', 'kilo...
#
#                                         miss_distance orbiting_body
# 0   {'astronomical': '0.0202143162', 'lunar': '7.8...         Earth
# 1   {'astronomical': '0.049656182', 'lunar': '19.3...         Earth
# 2   {'astronomical': '0.1345974227', 'lunar': '52....         Earth
# 3   {'astronomical': '0.2371472028', 'lunar': '92....         Earth
# 4   {'astronomical': '0.0643318776', 'lunar': '25....         Earth
# ..                                                ...           ...
# 19  {'astronomical': '0.2180335554', 'lunar': '84....         Earth
# 20  {'astronomical': '0.0346991631', 'lunar': '13....         Earth
# 21  {'astronomical': '0.0186063516', 'lunar': '7.2...         Earth
# 22  {'astronomical': '0.0858393146', 'lunar': '33....         Earth
# 23  {'astronomical': '0.1023551005', 'lunar': '39....         Earth
#
# [105 rows x 6 columns]

# %%
# unpack relative_velocity to new columns and drop relative_velocity

close_data = pd.concat([close_data.drop(['relative_velocity'], axis=1), close_data['relative_velocity'].apply(pd.Series)], axis=1)

# %%
# unpack miss_distance to new columns and drop miss_distance

close_data = pd.concat([close_data.drop(['miss_distance'], axis=1), close_data['miss_distance'].apply(pd.Series)], axis=1)

# %%
close_data
# Out:
#    close_approach_date close_approach_date_full  epoch_date_close_approach  \
# 0           2020-01-01        2020-Jan-01 21:18              1577913480000
# 1           2020-01-01        2020-Jan-01 22:49              1577918940000
# 2           2020-01-01        2020-Jan-01 14:55              1577890500000
# 3           2020-01-01        2020-Jan-01 15:16              1577891760000
# 4           2020-01-01        2020-Jan-01 14:36              1577889360000
# ..                 ...                      ...                        ...
# 19          2020-01-07        2020-Jan-07 14:26              1578407160000
# 20          2020-01-07        2020-Jan-07 15:00              1578409200000
# 21          2020-01-07        2020-Jan-07 07:46              1578383160000
# 22          2020-01-07        2020-Jan-07 18:45              1578422700000
# 23          2020-01-07        2020-Jan-07 11:30              1578396600000
#
#    orbiting_body kilometers_per_second kilometers_per_hour    miles_per_hour  \
# 0          Earth         15.3528156363    55270.1362905576  34342.7132967634
# 1          Earth          7.3167354067    26340.2474640716  16366.8054312171
# 2          Earth          5.0028249279    18010.1697403975  11190.8190811931
# 3          Earth         13.2987974369    47875.6707729516   29748.079986671
# 4          Earth         12.7904463668    46045.6069203144   28610.949477792
# ..           ...                   ...                 ...               ...
# 19         Earth         32.2682535309   116165.7127113599  72180.8563233447
# 20         Earth           22.16609708    79797.9494878484  49583.3425581578
# 21         Earth         12.0924879022    43532.9564477969  27049.6861883547
# 22         Earth         16.4090673576     59072.642487283  36705.4427721676
# 23         Earth           7.956450606     28643.222181446  17797.7843604657
#
#     astronomical          lunar          kilometers                miles
# 0   0.0202143162   7.8633690018   3024018.647026494   1879038.0551098572
# 1    0.049656182   19.316254798    7428459.05953234    4615830.420692692
# 2   0.1345974227  52.3583974303  20135487.743409649  12511611.9126011962
# 3   0.2371472028  92.2502618892  35476716.415338036  22044209.3769194568
# 4   0.0643318776  25.0251003864   9623911.862060712   5980021.5338013456
# ..           ...            ...                 ...                  ...
# 19  0.2180335554  84.8150530506  32617355.476366998  20267484.8772526524
# 20  0.0346991631  13.4979744459   5190920.890542597   3225488.6734859586
# 21  0.0186063516   7.2378707724   2783470.567831092   1729568.4096973896
# 22  0.0858393146  33.3914933794  12841378.626419902   7979262.6751305676
# 23  0.1023551005  39.8161340945  15312105.018435935    9514500.865188503
#
# [105 rows x 11 columns]

# %%
# concat neo_df and the unpacked close_data dataframes and drop close_approach_data column

neo = pd.concat([neo_df, close_data], axis =1)

# %%
neo
# Out:
#                                                 links       id  \
# 0   {'self': 'http://www.neowsapp.com/rest/v1/neo/...  3978225
# 1   {'self': 'http://www.neowsapp.com/rest/v1/neo/...  3972421
# 2   {'self': 'http://www.neowsapp.com/rest/v1/neo/...  3893737
# 3   {'self': 'http://www.neowsapp.com/rest/v1/neo/...  3976578
# 4   {'self': 'http://www.neowsapp.com/rest/v1/neo/...  3591759
# ..                                                ...      ...
# 19  {'self': 'http://www.neowsapp.com/rest/v1/neo/...  3893768
# 20  {'self': 'http://www.neowsapp.com/rest/v1/neo/...  3973548
# 21  {'self': 'http://www.neowsapp.com/rest/v1/neo/...  3976539
# 22  {'self': 'http://www.neowsapp.com/rest/v1/neo/...  3986636
# 23  {'self': 'http://www.neowsapp.com/rest/v1/neo/...  3893726
#
#    neo_reference_id         name  \
# 0           3978225   (2020 AN2)
# 1           3972421    (2020 AX)
# 2           3893737   (2019 WE5)
# 3           3976578   (2020 AE2)
# 4           3591759  (2011 YE40)
# ..              ...          ...
# 19          3893768   (2019 WH6)
# 20          3973548   (2020 AJ1)
# 21          3976539   (2020 AV1)
# 22          3986636   (2020 AD3)
# 23          3893726   (2019 WV4)
#
#                                      nasa_jpl_url  absolute_magnitude_h  \
# 0   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3978225                  26.5
# 1   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3972421                  26.3
# 2   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3893737                  23.0
# 3   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3976578                  22.9
# 4   http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3591759                  25.2
# ..                                            ...                   ...
# 19  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3893768                  18.8
# 20  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3973548                  23.3
# 21  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3976539                  26.0
# 22  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3986636                  21.7
# 23  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3893726                  23.5
#
#                                    estimated_diameter  \
# 0   {'kilometers': {'estimated_diameter_min': 0.01...
# 1   {'kilometers': {'estimated_diameter_min': 0.01...
# 2   {'kilometers': {'estimated_diameter_min': 0.06...
# 3   {'kilometers': {'estimated_diameter_min': 0.06...
# 4   {'kilometers': {'estimated_diameter_min': 0.02...
# ..                                                ...
# 19  {'kilometers': {'estimated_diameter_min': 0.46...
# 20  {'kilometers': {'estimated_diameter_min': 0.05...
# 21  {'kilometers': {'estimated_diameter_min': 0.01...
# 22  {'kilometers': {'estimated_diameter_min': 0.12...
# 23  {'kilometers': {'estimated_diameter_min': 0.05...
#
#     is_potentially_hazardous_asteroid  \
# 0                               False
# 1                               False
# 2                               False
# 3                               False
# 4                               False
# ..                                ...
# 19                              False
# 20                              False
# 21                              False
# 22                               True
# 23                              False
#
#                                   close_approach_data  is_sentry_object  ...  \
# 0   [{'close_approach_date': '2020-01-01', 'close_...             False  ...
# 1   [{'close_approach_date': '2020-01-01', 'close_...             False  ...
# 2   [{'close_approach_date': '2020-01-01', 'close_...             False  ...
# 3   [{'close_approach_date': '2020-01-01', 'close_...             False  ...
# 4   [{'close_approach_date': '2020-01-01', 'close_...             False  ...
# ..                                                ...               ...  ...
# 19  [{'close_approach_date': '2020-01-07', 'close_...             False  ...
# 20  [{'close_approach_date': '2020-01-07', 'close_...             False  ...
# 21  [{'close_approach_date': '2020-01-07', 'close_...             False  ...
# 22  [{'close_approach_date': '2020-01-07', 'close_...             False  ...
# 23  [{'close_approach_date': '2020-01-07', 'close_...             False  ...
#
#    close_approach_date_full epoch_date_close_approach  orbiting_body  \
# 0         2020-Jan-01 21:18             1577913480000          Earth
# 1         2020-Jan-01 22:49             1577918940000          Earth
# 2         2020-Jan-01 14:55             1577890500000          Earth
# 3         2020-Jan-01 15:16             1577891760000          Earth
# 4         2020-Jan-01 14:36             1577889360000          Earth
# ..                      ...                       ...            ...
# 19        2020-Jan-07 14:26             1578407160000          Earth
# 20        2020-Jan-07 15:00             1578409200000          Earth
# 21        2020-Jan-07 07:46             1578383160000          Earth
# 22        2020-Jan-07 18:45             1578422700000          Earth
# 23        2020-Jan-07 11:30             1578396600000          Earth
#
#    kilometers_per_second kilometers_per_hour    miles_per_hour  astronomical  \
# 0          15.3528156363    55270.1362905576  34342.7132967634  0.0202143162
# 1           7.3167354067    26340.2474640716  16366.8054312171   0.049656182
# 2           5.0028249279    18010.1697403975  11190.8190811931  0.1345974227
# 3          13.2987974369    47875.6707729516   29748.079986671  0.2371472028
# 4          12.7904463668    46045.6069203144   28610.949477792  0.0643318776
# ..                   ...                 ...               ...           ...
# 19         32.2682535309   116165.7127113599  72180.8563233447  0.2180335554
# 20           22.16609708    79797.9494878484  49583.3425581578  0.0346991631
# 21         12.0924879022    43532.9564477969  27049.6861883547  0.0186063516
# 22         16.4090673576     59072.642487283  36705.4427721676  0.0858393146
# 23           7.956450606     28643.222181446  17797.7843604657  0.1023551005
#
#             lunar          kilometers                miles
# 0    7.8633690018   3024018.647026494   1879038.0551098572
# 1    19.316254798    7428459.05953234    4615830.420692692
# 2   52.3583974303  20135487.743409649  12511611.9126011962
# 3   92.2502618892  35476716.415338036  22044209.3769194568
# 4   25.0251003864   9623911.862060712   5980021.5338013456
# ..            ...                 ...                  ...
# 19  84.8150530506  32617355.476366998  20267484.8772526524
# 20  13.4979744459   5190920.890542597   3225488.6734859586
# 21   7.2378707724   2783470.567831092   1729568.4096973896
# 22  33.3914933794  12841378.626419902   7979262.6751305676
# 23  39.8161340945  15312105.018435935    9514500.865188503
#
# [105 rows x 21 columns]

# %% [markdown]
# ### 2. Rename Columns

# %% [markdown]
# Rename some columns with titles lost from the dictionaries through mapping.

# %%
neo.rename(columns = {'kilometers_per_second': 'relative_velocity_kps',
                        'kilometers_per_hour': 'relative_velocity_kph',
                        'miles_per_hour': 'relative_velocity_mph',
                        'astronomical': 'miss_distance_astronomical',
                        'lunar': 'miss_distance_lunar',
                        'kilometers': 'miss_distance_k',
                        'miles': 'miss_distance_mi',
                     'close_approach_date_full': 'close_approach_date_time'}, inplace=True)

# %%
neo.head(2)
# Out:
#                                                links       id  \
# 0  {'self': 'http://www.neowsapp.com/rest/v1/neo/...  3978225
# 1  {'self': 'http://www.neowsapp.com/rest/v1/neo/...  3972421
#
#   neo_reference_id        name                                   nasa_jpl_url  \
# 0          3978225  (2020 AN2)  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3978225
# 1          3972421   (2020 AX)  http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3972421
#
#    absolute_magnitude_h                                 estimated_diameter  \
# 0                  26.5  {'kilometers': {'estimated_diameter_min': 0.01...
# 1                  26.3  {'kilometers': {'estimated_diameter_min': 0.01...
#
#    is_potentially_hazardous_asteroid  \
# 0                              False
# 1                              False
#
#                                  close_approach_data  is_sentry_object  ...  \
# 0  [{'close_approach_date': '2020-01-01', 'close_...             False  ...
# 1  [{'close_approach_date': '2020-01-01', 'close_...             False  ...
#
#   close_approach_date_time epoch_date_close_approach  orbiting_body  \
# 0        2020-Jan-01 21:18             1577913480000          Earth
# 1        2020-Jan-01 22:49             1577918940000          Earth
#
#   relative_velocity_kps relative_velocity_kph relative_velocity_mph  \
# 0         15.3528156363      55270.1362905576      34342.7132967634
# 1          7.3167354067      26340.2474640716      16366.8054312171
#
#   miss_distance_astronomical miss_distance_lunar    miss_distance_k  \
# 0               0.0202143162        7.8633690018  3024018.647026494
# 1                0.049656182        19.316254798   7428459.05953234
#
#      miss_distance_mi
# 0  1879038.0551098572
# 1   4615830.420692692
#
# [2 rows x 21 columns]

# %% [markdown]
# ### 3. Drop Columns

# %% [markdown]
# Drop columns not needed for my database.

# %%
neo.drop(labels=['links', 'id', 'nasa_jpl_url', 'absolute_magnitude_h', 'estimated_diameter', 'close_approach_data'], axis=1, inplace=True)

# %%
neo.head(2)
# Out:
#   neo_reference_id        name  is_potentially_hazardous_asteroid  \
# 0          3978225  (2020 AN2)                              False
# 1          3972421   (2020 AX)                              False
#
#    is_sentry_object close_approach_date close_approach_date_time  \
# 0             False          2020-01-01        2020-Jan-01 21:18
# 1             False          2020-01-01        2020-Jan-01 22:49
#
#    epoch_date_close_approach orbiting_body relative_velocity_kps  \
# 0              1577913480000         Earth         15.3528156363
# 1              1577918940000         Earth          7.3167354067
#
#   relative_velocity_kph relative_velocity_mph miss_distance_astronomical  \
# 0      55270.1362905576      34342.7132967634               0.0202143162
# 1      26340.2474640716      16366.8054312171                0.049656182
#
#   miss_distance_lunar    miss_distance_k    miss_distance_mi
# 0        7.8633690018  3024018.647026494  1879038.0551098572
# 1        19.316254798   7428459.05953234   4615830.420692692

# %% [markdown]
# ### 4. Key

# %% [markdown]
# Create a new name column that is the key to pair dataframes.

# %%
for value in neo['name']:
    print(value)
# Out:
# (2020 AN2)
# (2020 AX)
# (2019 WE5)
# (2020 AE2)
# (2011 YE40)
# (2013 EC20)
# (2016 EF195)
# (2011 HS60)
# (2020 AM1)
# (2020 AY1)
# (2019 YK)
# (2020 AP3)
# (2020 JU)
# (2019 YO6)
# (2020 BK2)
# 416591 (2004 LC2)
# (2003 UW29)
# (2011 YP10)
# (2012 DN31)
# (2016 TR55)
# (2015 XZ168)
# 506491 (2003 UW29)
# (2013 AW52)
# (2019 AE3)
# (2015 DY53)
# (2019 YH2)
# (2020 AD)
# (2020 AC)
# (2020 BS5)
# (2020 AC1)
# (2020 AP1)
# (2019 YL6)
# (2020 BD8)
# (2020 BN11)
# (2013 AB32)
# (2014 OY337)
# (2015 XR169)
# (2018 LH)
# (2013 AS27)
# (2015 XQ55)
# (2015 XF261)
# (2018 AU11)
# (2020 AP2)
# (2017 RV)
# (2019 YN4)
# (2020 BT2)
# (2020 AM2)
# (2020 AU2)
# (2006 QA31)
# (2020 AQ2)
# (2008 LW16)
# (2014 AD17)
# (2019 QC6)
# 468541 (2006 QA31)
# (2004 RO111)
# (2019 YB4)
# (2020 AN1)
# (2020 BE11)
# (2020 BH8)
# (2007 TE66)
# (2012 BU61)
# (2012 WH)
# (2019 OL3)
# (2017 YB2)
# (2019 AM8)
# 99942 Apophis (2004 MN4)
# (2015 YG)
# (2016 FA4)
# 538644 (2016 FA4)
# (2019 YM4)
# (2020 BM2)
# (2020 BU13)
# (2019 YW)
# (2012 AB11)
# (2017 YQ5)
# (2015 FE37)
# (2019 NB5)
# (2020 BZ6)
# (2019 WD5)
# (2020 AW)
# (2020 AU1)
# (2020 BJ3)
# (2019 QY4)
# (2006 WO3)
# (2009 AH16)
# (2020 BO3)
# (2020 BL1)
# (2015 YE18)
# (2016 NF22)
# (2019 YZ3)
# (2017 XU60)
# (2018 CA2)
# (2019 YT3)
# (2020 BV1)
# 481442 (2006 WO3)
# 512244 (2015 YE18)
# 281365 (2008 CM116)
# (2015 AJ44)
# (2013 CA88)
# (2019 KW)
# (2019 WH6)
# (2020 AJ1)
# (2020 AV1)
# (2020 AD3)
# (2019 WV4)

# %%
# create new column and drop the parenthesies

neo['name2'] = neo.name.str.replace("(", "")
neo['name2'] = neo.name2.str.replace(")", "")

# %%
neo.head(2)
# Out:
#   neo_reference_id        name  is_potentially_hazardous_asteroid  \
# 0          3978225  (2020 AN2)                              False
# 1          3972421   (2020 AX)                              False
#
#    is_sentry_object close_approach_date close_approach_date_time  \
# 0             False          2020-01-01        2020-Jan-01 21:18
# 1             False          2020-01-01        2020-Jan-01 22:49
#
#    epoch_date_close_approach orbiting_body relative_velocity_kps  \
# 0              1577913480000         Earth         15.3528156363
# 1              1577918940000         Earth          7.3167354067
#
#   relative_velocity_kph relative_velocity_mph miss_distance_astronomical  \
# 0      55270.1362905576      34342.7132967634               0.0202143162
# 1      26340.2474640716      16366.8054312171                0.049656182
#
#   miss_distance_lunar    miss_distance_k    miss_distance_mi     name2
# 0        7.8633690018  3024018.647026494  1879038.0551098572  2020 AN2
# 1        19.316254798   7428459.05953234   4615830.420692692   2020 AX

# %%
# create series of only the three digit name

digit = pd.Series(neo.name2, name = "digit")
three_digit_name = digit.str.split().str.get(-1)
three_digit_name
# Out:
# 0      AN2
# 1       AX
# 2      WE5
# 3      AE2
# 4     YE40
#       ...
# 19     WH6
# 20     AJ1
# 21     AV1
# 22     AD3
# 23     WV4
# Name: digit, Length: 105, dtype: object

# %%
# create a series of only the year

year = pd.Series(neo.name2, name='year')
year_name = year.str.split().str.get(-2)
year_name
# Out:
# 0     2020
# 1     2020
# 2     2019
# 3     2020
# 4     2011
#       ...
# 19    2019
# 20    2020
# 21    2020
# 22    2020
# 23    2019
# Name: year, Length: 105, dtype: object

# %%
# dataframe of both series

names = pd.concat([year_name, three_digit_name], axis=1)

# %%
names.head(2)
# Out:
#    year digit
# 0  2020   AN2
# 1  2020    AX

# %%
# join the two columns together with a space in between

names['date_digit'] = names[['year', 'digit']].apply(lambda x: ' '.join(x), axis = 1)

# %%
names.head(2)
# Out:
#    year digit date_digit
# 0  2020   AN2   2020 AN2
# 1  2020    AX    2020 AX

# %%
# one asteroid has an actual name, and needs to replace its year/digit combo.

names['date_digit'].replace({'2004 MN4':'Apophis'}, inplace=True)

# %%
for name in names['date_digit']:
    print(name)
# Out:
# 2020 AN2
# 2020 AX
# 2019 WE5
# 2020 AE2
# 2011 YE40
# 2013 EC20
# 2016 EF195
# 2011 HS60
# 2020 AM1
# 2020 AY1
# 2019 YK
# 2020 AP3
# 2020 JU
# 2019 YO6
# 2020 BK2
# 2004 LC2
# 2003 UW29
# 2011 YP10
# 2012 DN31
# 2016 TR55
# 2015 XZ168
# 2003 UW29
# 2013 AW52
# 2019 AE3
# 2015 DY53
# 2019 YH2
# 2020 AD
# 2020 AC
# 2020 BS5
# 2020 AC1
# 2020 AP1
# 2019 YL6
# 2020 BD8
# 2020 BN11
# 2013 AB32
# 2014 OY337
# 2015 XR169
# 2018 LH
# 2013 AS27
# 2015 XQ55
# 2015 XF261
# 2018 AU11
# 2020 AP2
# 2017 RV
# 2019 YN4
# 2020 BT2
# 2020 AM2
# 2020 AU2
# 2006 QA31
# 2020 AQ2
# 2008 LW16
# 2014 AD17
# 2019 QC6
# 2006 QA31
# 2004 RO111
# 2019 YB4
# 2020 AN1
# 2020 BE11
# 2020 BH8
# 2007 TE66
# 2012 BU61
# 2012 WH
# 2019 OL3
# 2017 YB2
# 2019 AM8
# Apophis
# 2015 YG
# 2016 FA4
# 2016 FA4
# 2019 YM4
# 2020 BM2
# 2020 BU13
# 2019 YW
# 2012 AB11
# 2017 YQ5
# 2015 FE37
# 2019 NB5
# 2020 BZ6
# 2019 WD5
# 2020 AW
# 2020 AU1
# 2020 BJ3
# 2019 QY4
# 2006 WO3
# 2009 AH16
# 2020 BO3
# 2020 BL1
# 2015 YE18
# 2016 NF22
# 2019 YZ3
# 2017 XU60
# 2018 CA2
# 2019 YT3
# 2020 BV1
# 2006 WO3
# 2015 YE18
# 2008 CM116
# 2015 AJ44
# 2013 CA88
# 2019 KW
# 2019 WH6
# 2020 AJ1
# 2020 AV1
# 2020 AD3
# 2019 WV4

# %%
# drop year and digit columns

names.drop(labels=['year', 'digit'], axis=1, inplace=True)

# %%
# rename date_digit to key

#names.rename(columns={'date_digit':'key'}, inplace=True)

# %%
names
# Out:
#    date_digit
# 0    2020 AN2
# 1     2020 AX
# 2    2019 WE5
# 3    2020 AE2
# 4   2011 YE40
# ..        ...
# 19   2019 WH6
# 20   2020 AJ1
# 21   2020 AV1
# 22   2020 AD3
# 23   2019 WV4
#
# [105 rows x 1 columns]

# %%
# concat neo df and names df

neo=pd.concat([neo, names], axis=1)

# %%
neo.head(2)
# Out:
#   neo_reference_id        name  is_potentially_hazardous_asteroid  \
# 0          3978225  (2020 AN2)                              False
# 1          3972421   (2020 AX)                              False
#
#    is_sentry_object close_approach_date close_approach_date_time  \
# 0             False          2020-01-01        2020-Jan-01 21:18
# 1             False          2020-01-01        2020-Jan-01 22:49
#
#    epoch_date_close_approach orbiting_body relative_velocity_kps  \
# 0              1577913480000         Earth         15.3528156363
# 1              1577918940000         Earth          7.3167354067
#
#   relative_velocity_kph relative_velocity_mph miss_distance_astronomical  \
# 0      55270.1362905576      34342.7132967634               0.0202143162
# 1      26340.2474640716      16366.8054312171                0.049656182
#
#   miss_distance_lunar    miss_distance_k    miss_distance_mi     name2  \
# 0        7.8633690018  3024018.647026494  1879038.0551098572  2020 AN2
# 1        19.316254798   7428459.05953234   4615830.420692692   2020 AX
#
#   date_digit
# 0   2020 AN2
# 1    2020 AX

# %%
# drop name and name2

neo.drop(labels=['name', 'name2'], axis=1, inplace=True)

# %%
# move key to the beginning of the df

key = neo['date_digit']
neo.drop(labels=['date_digit'], axis=1, inplace=True)
neo.insert(0, 'key', key)
neo.head(2)
# Out:
#         key neo_reference_id  is_potentially_hazardous_asteroid  \
# 0  2020 AN2          3978225                              False
# 1   2020 AX          3972421                              False
#
#    is_sentry_object close_approach_date close_approach_date_time  \
# 0             False          2020-01-01        2020-Jan-01 21:18
# 1             False          2020-01-01        2020-Jan-01 22:49
#
#    epoch_date_close_approach orbiting_body relative_velocity_kps  \
# 0              1577913480000         Earth         15.3528156363
# 1              1577918940000         Earth          7.3167354067
#
#   relative_velocity_kph relative_velocity_mph miss_distance_astronomical  \
# 0      55270.1362905576      34342.7132967634               0.0202143162
# 1      26340.2474640716      16366.8054312171                0.049656182
#
#   miss_distance_lunar    miss_distance_k    miss_distance_mi
# 0        7.8633690018  3024018.647026494  1879038.0551098572
# 1        19.316254798   7428459.05953234   4615830.420692692

# %% [markdown]
# ### 5. Datetime

# %% [markdown]
# Change columns with dates to datetime and add new columns based off of datetime.

# %%
neo.dtypes
# Out:
# key                                  object
# neo_reference_id                     object
# is_potentially_hazardous_asteroid      bool
# is_sentry_object                       bool
# close_approach_date                  object
# close_approach_date_time             object
# epoch_date_close_approach             int64
# orbiting_body                        object
# relative_velocity_kps                object
# relative_velocity_kph                object
# relative_velocity_mph                object
# miss_distance_astronomical           object
# miss_distance_lunar                  object
# miss_distance_k                      object
# miss_distance_mi                     object
# dtype: object

# %%
# change to datetime by astype

neo['close_approach_date'] = neo['close_approach_date'].astype('datetime64[ns]')

# %%
# change to datetime by pd.to_datetime

neo['close_approach_date_time']=pd.to_datetime(neo['close_approach_date_time'])

# %%
neo.dtypes
# Out:
# key                                          object
# neo_reference_id                             object
# is_potentially_hazardous_asteroid              bool
# is_sentry_object                               bool
# close_approach_date                  datetime64[ns]
# close_approach_date_time             datetime64[ns]
# epoch_date_close_approach                     int64
# orbiting_body                                object
# relative_velocity_kps                        object
# relative_velocity_kph                        object
# relative_velocity_mph                        object
# miss_distance_astronomical                   object
# miss_distance_lunar                          object
# miss_distance_k                              object
# miss_distance_mi                             object
# dtype: object

# %%
# add weekday column

neo['weekday']=neo['close_approach_date'].dt.strftime('%A')

# %%
# add full date and time column

neo['close_approach_date_full']=neo['close_approach_date_time'].dt.strftime('%c')

# %%
weekday = neo['weekday']
full = neo['close_approach_date_full']

# %%
# move weekday and close_approach_date_full to a new index position

neo.drop(labels=['weekday', 'close_approach_date_full'], axis=1, inplace=True)
neo.insert(6, 'weekday', weekday)
neo.insert(7, 'close_approach_date_full', full)
neo.head(2)
# Out:
#         key neo_reference_id  is_potentially_hazardous_asteroid  \
# 0  2020 AN2          3978225                              False
# 1   2020 AX          3972421                              False
#
#    is_sentry_object close_approach_date close_approach_date_time    weekday  \
# 0             False          2020-01-01      2020-01-01 21:18:00  Wednesday
# 1             False          2020-01-01      2020-01-01 22:49:00  Wednesday
#
#    close_approach_date_full  epoch_date_close_approach orbiting_body  \
# 0  Wed Jan  1 21:18:00 2020              1577913480000         Earth
# 1  Wed Jan  1 22:49:00 2020              1577918940000         Earth
#
#   relative_velocity_kps relative_velocity_kph relative_velocity_mph  \
# 0         15.3528156363      55270.1362905576      34342.7132967634
# 1          7.3167354067      26340.2474640716      16366.8054312171
#
#   miss_distance_astronomical miss_distance_lunar    miss_distance_k  \
# 0               0.0202143162        7.8633690018  3024018.647026494
# 1                0.049656182        19.316254798   7428459.05953234
#
#      miss_distance_mi
# 0  1879038.0551098572
# 1   4615830.420692692

# %%
neo.to_csv('neo.csv', index=False)

# %% [markdown]
# Resources:
#
# NASA. NASA APIs. Retrieved from https://api.nasa.gov/
